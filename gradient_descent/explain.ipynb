# %% [markdown]
# after getting loss , like square loss , log loss , then repeat it for every epoch ,

# %% [markdown]
# <img src="image2.png">

# %% [markdown]
# at 1st we take random w1 and w2 and bias then after the first epoch ,we use these , formula to set new value of these , so that loss can be less in every epoch

# %% [markdown]
# <img src="image.png" >

# %% [markdown]
# <img src="image3.png">

# %% [markdown]
# <img src="image4.png">

# %% [markdown]
# <img src="image5.png">

# %% [markdown]
# yeha mathi euta w1 ko lagi matra graph xa.w1 ra b lai eti tala laune mathi ko formula use garera ki , loss ko value purai minm hos

# %% [markdown]
# <img src="image6.png">

# %% [markdown]
# hami le pratek ko slope nikalxau ra tehi anusar minm point ma janxau , slope vaneko diff ho ,so tehi vaera formula ma hami sabai lai diff le minus garxau
